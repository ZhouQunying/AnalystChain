# %%
from dotenv import load_dotenv

load_dotenv("../../config/.env")
# Out:
# True

# %%
from openai import OpenAI
from langsmith import traceable
from langsmith.wrappers import wrap_openai

openai_client = wrap_openai(OpenAI())

def retriever(query: str):
    results = ["西恩在阿里巴巴工作"]
    return results

@traceable
def rag(question):
    docs = retriever(question)
    system_message = """仅使用提供的以下信息回答用户的问题:
    {docs}""".format(docs="\n".join(docs))

    return openai_client.chat.completions.create(
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": question},
        ],
        model="gpt-4o-mini",
    )

rag("西恩在哪工作")
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 from openai import OpenAI
#       2 from langsmith.wrappers import wrap_openai
# ----> 4 openai_client = wrap_openai(OpenAI())
#       6 def retriever(query: str):
#       7     results = ["西恩在阿里巴巴工作"]
#
# File /usr/local/Caskroom/miniconda/base/envs/analyst_chain/lib/python3.13/site-packages/openai/_client.py:130, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     128     api_key = os.environ.get("OPENAI_API_KEY")
#     129 if api_key is None:
# --> 130     raise OpenAIError(
#     131         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     132     )
#     133 self.api_key = api_key
#     135 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
